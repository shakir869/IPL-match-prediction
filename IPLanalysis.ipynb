# %% [markdown]
# | Attribute / Function | Easy Definition                                |
# | -------------------- | ---------------------------------------------- |
# | `data.shape`         | Returns number of rows and columns             |
# | `data.size`          | Returns total number of elements               |
# | `data.ndim`          | Returns number of dimensions                   |
# | `data.columns`       | Returns column names                           |
# | `data.index`         | Returns row index                              |
# | `data.dtypes`        | Returns data type of each column               |
# | `data.info()`        | Gives summary of dataset                       |
# | `data.describe()`    | Gives statistical summary of numerical columns |
# | `data.head()`        | Shows first 5 rows                             |
# | `data.tail()`        | Shows last 5 rows                              |
# | `data.sample()`      | Shows random rows                              |

# %% [markdown]
# | Function                | Easy Definition                            |
# | ----------------------- | ------------------------------------------ |
# | `data["column"]`        | Selects one column                         |
# | `data[["col1","col2"]]` | Selects multiple columns                   |
# | `data.loc[]`            | Selects rows/columns using labels          |
# | `data.iloc[]`           | Selects rows/columns using index positions |
# | `data.at[]`             | Accesses a single value using label        |
# | `data.iat[]`            | Accesses a single value using position     |

# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("matches - matches.csv")
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
data.ndim
data['winner'].ndim
# Out:
# 1

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    str
#  3   date             636 non-null    str
#  4   team1            636 non-null    str
#  5   team2            636 non-null    str
#  6   toss_winner      636 non-null    str
#  7   toss_decision    636 non-null    str
#  8   result           636 non-null    str
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    str
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    str
#  14  venue            636 non-null    str
#  15  umpire1          635 non-null    str
#  16  umpire2          635 non-null    str
#  17  umpire3          0 non-null      float64
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: str

# %%
type(data['winner'])
# Out:
# pandas.Series

# %%
data[['team1','team2','winner']]
print(type(data[['team1','team2','winner']]))
# Out:
# <class 'pandas.DataFrame'>

# %%
(data['winner']).shape
# Out:
# (636,)

# %%
data.iloc[[1,3,7,9]]
# Out:
#    id  season    city        date                        team1  \
# 1   2    2017    Pune  2017-04-06               Mumbai Indians
# 3   4    2017  Indore  2017-04-08       Rising Pune Supergiant
# 7   8    2017  Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# ...

# %%
data.iloc[[2,3,5,7,9,23,67,87],[4,5,10]]
# Out:
#                           team1                        team2  \
# 2                 Gujarat Lions        Kolkata Knight Riders
# 3        Rising Pune Supergiant              Kings XI Punjab
# 5                 Gujarat Lions          Sunrisers Hyderabad
# 7   Royal Challengers Bangalore              Kings XI Punjab
# 9           Sunrisers Hyderabad               Mumbai Indians
# 23               Mumbai Indians             Delhi Daredevils
# 67              Deccan Chargers             Rajasthan Royals
# 87        Kolkata Knight Riders  Royal Challengers Bangalore
#
#                    winner
# 2   Kolkata Knight Riders
# 3         Kings XI Punjab
# 5     Sunrisers Hyderabad
# 7         Kings XI Punjab
# 9          Mumbai Indians
# 23         Mumbai Indians
# 67       Rajasthan Royals
# 87  Kolkata Knight Riders

# %%
shakir= data['city'] =='Indore'
data[shakir]
# Out:
#       id  season    city        date                        team1  \
# 3      4    2017  Indore  2017-04-08       Rising Pune Supergiant
# 7      8    2017  Indore  2017-04-10  Royal Challengers Bangalore
# 21    22    2017  Indore  2017-04-20              Kings XI Punjab
# 289  290    2011  Indore  2011-05-13         Kochi Tuskers Kerala
# 293  294    2011  Indore  2011-05-15             Rajasthan Royals
#
#                     team2                  toss_winner toss_decision  result  \
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 21         Mumbai Indians               Mumbai Indians         field  normal
# 289       Kings XI Punjab              Kings XI Punjab         field  normal
# 293  Kochi Tuskers Kerala         Kochi Tuskers Kerala         field  normal
#
#      dl_applied                winner  win_by_runs  win_by_wickets  \
# ...

# %%
def get_city_match_count(city):
    mask= data['city'] ==city
    return data[mask].shape[0]

# %%
get_city_match_count('Hyderabad')
# Out:
# 49

# %%
mask1= data['city'] =='Hyderabad'
mask2= data['date'] >'2010-01-01'
data[mask1 & mask2].shape[0]
# Out:
# 42

# %%
data.loc[0:2, ["winner", "city"]]
# Out:
#                    winner       city
# 0     Sunrisers Hyderabad  Hyderabad
# 1  Rising Pune Supergiant       Pune
# 2   Kolkata Knight Riders     Rajkot

# %%
data.iloc[0:0,0:18]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
data[data['win_by_wickets'].between(5,7)]
# Out:
#       id  season        city        date                   team1  \
# 1      2    2017        Pune  2017-04-06          Mumbai Indians
# 3      4    2017      Indore  2017-04-08  Rising Pune Supergiant
# 12    13    2017      Rajkot  2017-04-14  Rising Pune Supergiant
# 15    16    2017      Mumbai  2017-04-16           Gujarat Lions
# 24    25    2017        Pune  2017-04-22     Sunrisers Hyderabad
# ..   ...     ...         ...         ...                     ...
# 621  622    2016  Chandigarh  2016-05-15         Kings XI Punjab
# 626  627    2016      Kanpur  2016-05-19   Kolkata Knight Riders
# 627  628    2016      Raipur  2016-05-20     Sunrisers Hyderabad
# 629  630    2016      Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016      Raipur  2016-05-22        Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
data["season"].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
# data["city"].unique()       # unique values
# data["city"].nunique()      # number of unique values
data["city"].value_counts().sort_values() # frequency of each value
# Out:
# city
# Bloemfontein       2
# Nagpur             3
# East London        3
# Kimberley          3
# Kanpur             4
# Indore             5
# Kochi              5
# Raipur             6
# Sharjah            6
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Abu Dhabi          7
# Cape Town          7
# Johannesburg       8
# Dharamsala         9
# Rajkot            10
# Visakhapatnam     11
# Centurion         12
# Ahmedabad         12
# Durban            15
# Pune              32
# Jaipur            33
# Chandigarh        46
# Chennai           48
# Hyderabad         49
# Delhi             60
# Kolkata           61
# Bangalore         66
# Mumbai            85
# Name: count, dtype: int64

# %%
# find the matches winer byt he mumbai

data[data["winner"]=="Mumbai Indians"].head(5)
# Out:
#     id  season       city        date                        team1  \
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
# 21  22    2017     Indore  2017-04-20              Kings XI Punjab
#
#              team2     toss_winner toss_decision  result  dl_applied  \
# 6   Mumbai Indians  Mumbai Indians         field  normal           0
# 9   Mumbai Indians  Mumbai Indians         field  normal           0
# 11  Mumbai Indians  Mumbai Indians         field  normal           0
# 15  Mumbai Indians  Mumbai Indians         field  normal           0
# 21  Mumbai Indians  Mumbai Indians         field  normal           0
#
#             winner  win_by_runs  win_by_wickets player_of_match  \
# 6   Mumbai Indians            0               4          N Rana
# ...

# %%
data.groupby("winner")["win_by_runs"].mean().sort_values(
    ascending=False
).head()
# Out:
# winner
# Chennai Super Kings            20.088608
# Mumbai Indians                 16.652174
# Royal Challengers Bangalore    16.383562
# Deccan Chargers                14.517241
# Rajasthan Royals               13.031746
# Name: win_by_runs, dtype: float64

# %%
data.pivot_table(
    values="win_by_runs",
    index="winner",
    columns="city",
    aggfunc="mean"
).head(5)
# Out:
# city                 Abu Dhabi  Ahmedabad  Bangalore  Bloemfontein  Cape Town  \
# winner
# Chennai Super Kings       93.0        NaN  19.500000           NaN        NaN
# Deccan Chargers            NaN        NaN   0.000000           NaN       12.0
# Delhi Daredevils           NaN        0.0   5.666667          14.0        0.0
# Gujarat Lions              NaN        NaN   0.000000           NaN        NaN
# Kings XI Punjab           11.5        0.0  10.200000           0.0       27.0
#
# city                 Centurion  Chandigarh    Chennai    Cuttack      Delhi  \
# winner
# Chennai Super Kings       25.0   11.000000  17.484848        NaN  26.800000
# Deccan Chargers            9.5         NaN  15.500000   9.666667  13.500000
# Delhi Daredevils           0.0    0.000000   0.000000        NaN  15.869565
# Gujarat Lions              NaN    0.000000        NaN        NaN   1.000000
# Kings XI Punjab            NaN   13.863636   3.500000  44.000000   1.500000
#
# ...

# %%
import matplotlib as plt

# %%
data["winner"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['toss_decision'].value_counts().plot(kind ='pie')
# Out:
# <Axes: >

# %%
data.sort_values(["city", "win_by_runs"]).tail(5)
# Out:
#       id  season city        date                        team1  \
# 469  470    2014  NaN  2014-04-25               Mumbai Indians
# 474  475    2014  NaN  2014-04-28  Royal Challengers Bangalore
# 468  469    2014  NaN  2014-04-25          Sunrisers Hyderabad
# 466  467    2014  NaN  2014-04-23          Chennai Super Kings
# 476  477    2014  NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2          toss_winner toss_decision  result  \
# 469  Chennai Super Kings       Mumbai Indians           bat  normal
# 474      Kings XI Punjab      Kings XI Punjab         field  normal
# 468     Delhi Daredevils  Sunrisers Hyderabad           bat  normal
# 466     Rajasthan Royals     Rajasthan Royals         field  normal
# 476       Mumbai Indians       Mumbai Indians         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 469           0  Chennai Super Kings            0               7
# ...

# %%
data.drop_duplicates(['city','season'])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 591  592    2016           Pune  2016-04-22  Royal Challengers Bangalore
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians
